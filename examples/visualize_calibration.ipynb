# %%
import numpy as np
import matplotlib.pyplot as plt
import cmocean as cmo

# %%
mean_q_profile = np.load('mean_q_profiles_2023_07.npz')['typical_profiles']
altitude = np.load('mean_q_profiles_2023_07.npz')['alt_grid']

# %%
plt.figure(dpi=150)
plt.imshow(mean_q_profile.T * 1e3, aspect='auto', cmap=cmo.cm.algae_r,
    extent=(0, 23, altitude[0], altitude[-1]), origin='lower')
plt.xlabel('Time (UTC hours)')
plt.ylabel('Altitude (m)')
plt.colorbar(label='Typical specific humidity (g/kg)')
plt.title('ERA-5 Specific Humidity Profile, Atacama, July 2023')
plt.show()

# %%
import atmo3 as a3

# %%
delta_q_profile = np.load('delta_q_profiles_2023_07.npz')['delta_q_map']
altitude = np.load('delta_q_profiles_2023_07.npz')['alt_grid']

# %%
plt.imshow(delta_q_profile.T * 1e3, aspect='auto', cmap=cmo.cm.algae_r,
    extent=(0, 23, altitude[0], altitude[-1]), origin='lower')
plt.xlabel('Time (UTC hours)')
plt.ylabel('Altitude (m)')
plt.colorbar(label='Standard deviation of specific humidity (g/kg)')
plt.title('Standard Deviation of Specific Humidity Profile, July 2023')
plt.show()

# %%
mean_ta_profile = np.load('mean_ta_profiles_2023_07.npz')['typical_profiles']
altitude = np.load('mean_ta_profiles_2023_07.npz')['alt_grid']

# %%
plt.imshow(mean_ta_profile.T, aspect='auto', cmap=cmo.cm.algae_r,
    extent=(0, 23, altitude[0], altitude[-1]),
    origin='lower')
plt.xlabel('Time (UTC hours)')
plt.ylabel('Altitude (m)')
plt.colorbar(label='Typical temperature (K)')
plt.title('Typical Temperature Profile, July 2023')
plt.show()
